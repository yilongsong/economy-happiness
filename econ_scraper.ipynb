# %%
import pandas as pd
import re
import string

# %%
df = pd.read_csv('WEO_Data.csv')
df.head()
# Out:
#        Country                       Subject Descriptor  \
# 0  Afghanistan  Gross domestic product, constant prices
# 1  Afghanistan  Gross domestic product, constant prices
# 2  Afghanistan   Gross domestic product, current prices
# 3  Afghanistan   Gross domestic product, current prices
# 4  Afghanistan   Gross domestic product, current prices
#
#                                             Units     Scale  \
# 0                               National currency  Billions
# 1                                  Percent change       NaN
# 2                               National currency  Billions
# 3                                    U.S. dollars  Billions
# 4  Purchasing power parity; international dollars  Billions
#
#                        Country/Series-specific Notes     2010     2011  \
# 0  Source: National Statistics Office Latest actu...  899.956  958.266
# 1  See notes for:  Gross domestic product, consta...    8.438    6.479
# 2  Source: National Statistics Office Latest actu...  711.759  836.222
# 3  See notes for:  Gross domestic product, curren...   15.325    17.89
# 4  See notes for:  Gross domestic product, curren...   46.309   50.334
#
#        2012      2013      2014      2015      2016      2017      2018  \
# 0  1,092.12  1,154.18  1,185.31  1,197.01  1,222.92  1,255.29  1,270.22
# 1    13.968     5.683     2.697     0.988     2.164     2.647     1.189
# 2  1,033.59  1,116.83  1,183.04  1,226.57  1,222.92  1,285.46  1,327.69
# 3    20.293     20.17    20.616    20.057     18.02    18.883    18.401
# 4    59.945    63.784    69.444    72.056    70.098    74.712    77.418
#
#        2019      2020 2021 2022  Estimates Start After
# 0  1,319.90  1,288.87  NaN  NaN                 2020.0
# 1     3.912    -2.351  NaN  NaN                 2020.0
# 2  1,469.60  1,547.29  NaN  NaN                 2020.0
# 3    18.876    20.136  NaN  NaN                 2020.0
# 4    81.889    81.007  NaN  NaN                 2020.0

# %%
#standardise column names
def standardise_column_names(df, remove_punct=True):
    translator = str.maketrans(string.punctuation, ' '*len(string.punctuation))

    for c in df.columns:
        c_mod = c.lower()
        if remove_punct:            
            c_mod = c_mod.translate(translator)
        c_mod = '_'.join(c_mod.split(' '))
        if c_mod[-1] == '_':
            c_mod = c_mod[:-1]
        c_mod = re.sub(r'\_+', '_', c_mod)
        df.rename({c: c_mod}, inplace=True, axis=1)
    return df

standardise_column_names(df)
# Out:
#                                                 country  \
# 0                                           Afghanistan
# 1                                           Afghanistan
# 2                                           Afghanistan
# 3                                           Afghanistan
# 4                                           Afghanistan
# ...                                                 ...
# 8621                                           Zimbabwe
# 8622                                           Zimbabwe
# 8623                                           Zimbabwe
# 8624                                                NaN
# 8625  International Monetary Fund, World Economic Ou...
#
#                                      subject_descriptor  \
# 0               Gross domestic product, constant prices
# 1               Gross domestic product, constant prices
# 2                Gross domestic product, current prices
# 3                Gross domestic product, current prices
# 4                Gross domestic product, current prices
# ...                                                 ...
# 8621  Gross domestic product corresponding to fiscal...
# 8622                            Current account balance
# 8623                            Current account balance
# 8624                                                NaN
# 8625                                                NaN
#
#                                                units     scale  \
# 0                                  National currency  Billions
# 1                                     Percent change       NaN
# 2                                  National currency  Billions
# 3                                       U.S. dollars  Billions
# 4     Purchasing power parity; international dollars  Billions
# ...                                              ...       ...
# 8621                               National currency  Billions
# 8622                                    U.S. dollars  Billions
# 8623                                  Percent of GDP       NaN
# 8624                                             NaN       NaN
# 8625                                             NaN       NaN
#
#                           country_series_specific_notes     2010     2011  \
# 0     Source: National Statistics Office Latest actu...  899.956  958.266
# 1     See notes for:  Gross domestic product, consta...    8.438    6.479
# 2     Source: National Statistics Office Latest actu...  711.759  836.222
# 3     See notes for:  Gross domestic product, curren...   15.325    17.89
# 4     See notes for:  Gross domestic product, curren...   46.309   50.334
# ...                                                 ...      ...      ...
# 8621  Source: Ministry of Finance or Treasury Latest...   12.042     14.1
# 8622  Source: Reserve Bank of Zimbabwe and Ministry ...   -1.655    -2.75
# 8623  See notes for:  Gross domestic product, curren...  -13.747    -19.5
# 8624                                                NaN      NaN      NaN
# 8625                                                NaN      NaN      NaN
#
#           2012      2013      2014      2015      2016      2017      2018  \
# 0     1,092.12  1,154.18  1,185.31  1,197.01  1,222.92  1,255.29  1,270.22
# 1       13.968     5.683     2.697     0.988     2.164     2.647     1.189
# 2     1,033.59  1,116.83  1,183.04  1,226.57  1,222.92  1,285.46  1,327.69
# 3       20.293     20.17    20.616    20.057     18.02    18.883    18.401
# 4       59.945    63.784    69.444    72.056    70.098    74.712    77.418
# ...        ...       ...       ...       ...       ...       ...       ...
# 8621    17.116    19.093    19.499    19.969    20.555    21.385    36.945
# 8622    -2.278    -2.649    -2.334    -1.597    -0.697    -0.271     -1.38
# 8623   -13.307   -13.873   -11.969    -7.996    -3.393    -1.268    -3.734
# 8624       NaN       NaN       NaN       NaN       NaN       NaN       NaN
# 8625       NaN       NaN       NaN       NaN       NaN       NaN       NaN
#
#           2019      2020      2021       2022  estimates_start_after
# 0     1,319.90  1,288.87       NaN        NaN                 2020.0
# 1        3.912    -2.351       NaN        NaN                 2020.0
# 2     1,469.60  1,547.29       NaN        NaN                 2020.0
# 3       18.876    20.136       NaN        NaN                 2020.0
# 4       81.889    81.007       NaN        NaN                 2020.0
# ...        ...       ...       ...        ...                    ...
# 8621   212.173  1,378.80  3,185.62  12,889.98                 2021.0
# 8622      0.92     0.678     0.348      0.267                 2021.0
# 8623     3.536     2.524     0.968      0.808                 2021.0
# 8624       NaN       NaN       NaN        NaN                    NaN
# 8625       NaN       NaN       NaN        NaN                    NaN
#
# [8626 rows x 19 columns]

# %%
#deal with missing values
df["subject_descriptor"] = df["subject_descriptor"].fillna("")
df
# Out:
#                                                 country  \
# 0                                           Afghanistan
# 1                                           Afghanistan
# 2                                           Afghanistan
# 3                                           Afghanistan
# 4                                           Afghanistan
# ...                                                 ...
# 8621                                           Zimbabwe
# 8622                                           Zimbabwe
# 8623                                           Zimbabwe
# 8624                                                NaN
# 8625  International Monetary Fund, World Economic Ou...
#
#                                      subject_descriptor  \
# 0               Gross domestic product, constant prices
# 1               Gross domestic product, constant prices
# 2                Gross domestic product, current prices
# 3                Gross domestic product, current prices
# 4                Gross domestic product, current prices
# ...                                                 ...
# 8621  Gross domestic product corresponding to fiscal...
# 8622                            Current account balance
# 8623                            Current account balance
# 8624
# 8625
#
#                                                units     scale  \
# 0                                  National currency  Billions
# 1                                     Percent change       NaN
# 2                                  National currency  Billions
# 3                                       U.S. dollars  Billions
# 4     Purchasing power parity; international dollars  Billions
# ...                                              ...       ...
# 8621                               National currency  Billions
# 8622                                    U.S. dollars  Billions
# 8623                                  Percent of GDP       NaN
# 8624                                             NaN       NaN
# 8625                                             NaN       NaN
#
#                           country_series_specific_notes     2010     2011  \
# 0     Source: National Statistics Office Latest actu...  899.956  958.266
# 1     See notes for:  Gross domestic product, consta...    8.438    6.479
# 2     Source: National Statistics Office Latest actu...  711.759  836.222
# 3     See notes for:  Gross domestic product, curren...   15.325    17.89
# 4     See notes for:  Gross domestic product, curren...   46.309   50.334
# ...                                                 ...      ...      ...
# 8621  Source: Ministry of Finance or Treasury Latest...   12.042     14.1
# 8622  Source: Reserve Bank of Zimbabwe and Ministry ...   -1.655    -2.75
# 8623  See notes for:  Gross domestic product, curren...  -13.747    -19.5
# 8624                                                NaN      NaN      NaN
# 8625                                                NaN      NaN      NaN
#
#           2012      2013      2014      2015      2016      2017      2018  \
# 0     1,092.12  1,154.18  1,185.31  1,197.01  1,222.92  1,255.29  1,270.22
# 1       13.968     5.683     2.697     0.988     2.164     2.647     1.189
# 2     1,033.59  1,116.83  1,183.04  1,226.57  1,222.92  1,285.46  1,327.69
# 3       20.293     20.17    20.616    20.057     18.02    18.883    18.401
# 4       59.945    63.784    69.444    72.056    70.098    74.712    77.418
# ...        ...       ...       ...       ...       ...       ...       ...
# 8621    17.116    19.093    19.499    19.969    20.555    21.385    36.945
# 8622    -2.278    -2.649    -2.334    -1.597    -0.697    -0.271     -1.38
# 8623   -13.307   -13.873   -11.969    -7.996    -3.393    -1.268    -3.734
# 8624       NaN       NaN       NaN       NaN       NaN       NaN       NaN
# 8625       NaN       NaN       NaN       NaN       NaN       NaN       NaN
#
#           2019      2020      2021       2022  estimates_start_after
# 0     1,319.90  1,288.87       NaN        NaN                 2020.0
# 1        3.912    -2.351       NaN        NaN                 2020.0
# 2     1,469.60  1,547.29       NaN        NaN                 2020.0
# 3       18.876    20.136       NaN        NaN                 2020.0
# 4       81.889    81.007       NaN        NaN                 2020.0
# ...        ...       ...       ...        ...                    ...
# 8621   212.173  1,378.80  3,185.62  12,889.98                 2021.0
# 8622      0.92     0.678     0.348      0.267                 2021.0
# 8623     3.536     2.524     0.968      0.808                 2021.0
# 8624       NaN       NaN       NaN        NaN                    NaN
# 8625       NaN       NaN       NaN        NaN                    NaN
#
# [8626 rows x 19 columns]

# %%
print(df["subject_descriptor"].unique())
# Out:
# ['Gross domestic product, constant prices'
#  'Gross domestic product, current prices'
#  'Gross domestic product, deflator'
#  'Gross domestic product per capita, constant prices'
#  'Gross domestic product per capita, current prices'
#  'Output gap in percent of potential GDP'
#  'Gross domestic product based on purchasing-power-parity (PPP) share of world total'
#  'Implied PPP conversion rate' 'Total investment' 'Gross national savings'
#  'Inflation, average consumer prices'
#  'Inflation, end of period consumer prices'
#  'Volume of imports of goods and services' 'Volume of Imports of goods'
#  'Volume of exports of goods and services' 'Volume of exports of goods'
#  'Unemployment rate' 'Employment' 'Population'
#  'General government revenue' 'General government total expenditure'
#  'General government net lending/borrowing'
#  'General government structural balance'
#  'General government primary net lending/borrowing'
#  'General government net debt' 'General government gross debt'
#  'Gross domestic product corresponding to fiscal year, current prices'
#  'Current account balance' '']

# %%
#filter by subject descriptor
mask1 = df["subject_descriptor"].str.contains("Gross domestic product per capita, current prices")
mask2 = df["subject_descriptor"].str.contains("Inflation, average consumer prices")
mask3 = df["subject_descriptor"].str.contains("Unemployment rate")
#combine all the rows that satisfy any of the masks
df = df[mask1 | mask2 | mask3]

#filter by units
mask4 =  df["units"].str.contains("U.S. dollars")
mask5 =  df["units"].str.contains("Index")

#combine all the rows that satisfy any of the masks
df = df[mask3 | mask4 | mask5]
df
# Out:
# /var/folders/ll/_15vm2qs6bgbljw854xmcf9m0000gn/T/ipykernel_13862/1343359832.py:13: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   df = df[mask3 | mask4 | mask5]
#           country                                 subject_descriptor  \
# 9     Afghanistan  Gross domestic product per capita, current prices
# 16    Afghanistan                 Inflation, average consumer prices
# 24    Afghanistan                                  Unemployment rate
# 53        Albania  Gross domestic product per capita, current prices
# 60        Albania                 Inflation, average consumer prices
# ...           ...                                                ...
# 8552       Zambia                 Inflation, average consumer prices
# 8560       Zambia                                  Unemployment rate
# 8589     Zimbabwe  Gross domestic product per capita, current prices
# 8596     Zimbabwe                 Inflation, average consumer prices
# 8604     Zimbabwe                                  Unemployment rate
#
#                              units  scale  \
# 9                     U.S. dollars  Units
# 16                           Index    NaN
# 24    Percent of total labor force    NaN
# 53                    U.S. dollars  Units
# 60                           Index    NaN
# ...                            ...    ...
# 8552                         Index    NaN
# 8560  Percent of total labor force    NaN
# 8589                  U.S. dollars  Units
# 8596                         Index    NaN
# 8604  Percent of total labor force    NaN
#
#                           country_series_specific_notes      2010      2011  \
# 9     See notes for:  Gross domestic product, curren...    631.49     714.7
# 16    Source: National Statistics Office Latest actu...    76.229    85.227
# 24                                                  NaN       NaN       NaN
# 53    See notes for:  Gross domestic product, curren...  4,097.83  4,439.89
# 60    Source: National Statistics Office Latest actu...      89.8    92.892
# ...                                                 ...       ...       ...
# 8552  Source: National Statistics Office Latest actu...   105.956    115.13
# 8560                                                NaN       NaN       NaN
# 8589  See notes for:  Gross domestic product, curren...   975.851  1,131.68
# 8596  Source: National Statistics Office Latest actu...    56.148    58.097
# 8604                                                NaN       NaN       NaN
#
#           2012      2013      2014      2015      2016      2017      2018  \
# 9      784.611   754.402   746.922   705.597   617.126   635.789   582.323
# 16      90.717    97.417    101.97   101.296   105.736   110.998   111.693
# 24         NaN       NaN       NaN       NaN       NaN       NaN       NaN
# 53    4,248.91  4,415.60  4,584.92  3,953.61  4,124.41  4,525.89  5,257.71
# 60      94.783    96.608    98.167       100   101.287   103.297   105.393
# ...        ...       ...       ...       ...       ...       ...       ...
# 8552     122.7   131.263   141.515   155.818   183.662   195.742   210.412
# 8560       NaN       NaN       NaN       NaN       NaN       NaN       NaN
# 8589  1,310.44  1,421.70  1,415.28  1,425.47  1,444.72  1,481.24  2,523.25
# 8596    60.258    61.241    61.111    59.638    58.709    59.242    65.526
# 8604       NaN       NaN       NaN       NaN       NaN       NaN       NaN
#
#           2019      2020      2021      2022  estimates_start_after
# 9      586.204   611.268       NaN       NaN                 2019.0
# 16     114.264   120.671       NaN       NaN                 2020.0
# 24         NaN       NaN       NaN       NaN                    NaN
# 53    5,345.06  5,268.24  6,373.30  6,457.22                 2021.0
# 60      106.88   108.613   110.831   118.286                 2022.0
# ...        ...       ...       ...       ...                    ...
# 8552   229.666   265.798   324.329   359.983                 2021.0
# 8560       NaN       NaN       NaN       NaN                    NaN
# 8589  1,746.51  1,769.57  2,321.63  2,087.67                 2017.0
# 8596   232.807  1,530.03  3,037.82  8,912.93                 2022.0
# 8604       NaN       NaN       NaN       NaN                    NaN
#
# [588 rows x 19 columns]
